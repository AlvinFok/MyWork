# %%
import requests
import pymongo
from pymongo import MongoClient
client= MongoClient('localhost', 27017)
db = client['test-database']
collection = db['test-collection']

# %%
import requests
from bs4 import BeautifulSoup

# %%
req=requests.get('http://news.fcu.edu.tw/wSite/lp?ctNode=15361&mp=9000')
print(req.text)
# Out:
# <!DOCTYPE html><html>
# <head>
# <META http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title>逢甲大學新聞中心-校園活動</title>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0; user-scalable=0;">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="description" content="">
# <meta name="author" content="">
# <meta name="DC.Title" content="校園活動">
# <meta name="DC.Subject" content="校園活動">
# <meta name="DC.Creator" content="系統使用者">
# <meta name="DC.Description" content="">
# <meta name="DC.Publisher" content="逢甲大學">
# <meta name="DC.Contributor" content="">
# <meta name="DC.Date" content="2009-08-24 00:00:00.0">
# <meta name="DC.Type" content="文字">
# <meta name="DC.Format" content="">
# <meta name="DC.Identifier" content="">
# <meta name="DC.Relation" content="">
# <meta name="DC.Source" content="">
# <meta name="DC.Language" content="">
# <meta name="DC.Coverage" content="">
# <meta name="DC.Rights" content="">
# <meta name="Category.Theme" content="">
# <meta name="Category.Cake" content="">
# <meta name="Category.Service" content="">
# <link rel="stylesheet" type="text/css" href="styles/fcu_www_rwd_all/css/bootstrap.min.css">
# <link rel="stylesheet" type="text/css" href="styles/fcu_www_rwd_all/css/style.css">
# <link rel="stylesheet" type="text/css" media="screen" href="styles/fcu_www_rwd_all/css/flexslider.css">
# <link rel="stylesheet" type="text/css" media="screen" href="styles/fcu_www_rwd_all/css/demo.css">
# <script type="text/javascript" src="styles/fcu_www_rwd_all/js/jquery.js"></script><script type="text/javascript" src="styles/fcu_www_rwd_all/js/jquery1.11.1.js"></script><script type="text/javascript" src="styles/fcu_www_rwd_all/js/bootstrap.min.js"></script><script defer="true" src="styles/fcu_www_rwd_all/js/jquery.flexslider.js">
# 		</script><script type="text/javascript" src="styles/fcu_www_rwd_all/js/modernizr.custom.js"></script><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script><script type="text/javascript" src="styles/fcu_www_rwd_all/js/cbpHorizontalMenu.min.js"></script><script language="javascript">
# 			$(function() {
# 				cbpHorizontalMenu.init();
# 			});
# 		</script>
# </head>
# <body>
# <header>
# <nav>
# <div class="container navbg">
# <div class="row">
# <div class="col-md-12 column">
# <nav class="navbar navbar-default" role="navigation">
# <div class="navbar-header">
# <button type="button" class="navbar-toggle" data-toggle="collapse" data-target=".navbar-ex1-collapse"><span class="sr-only">導覽列開關</span><span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button><a class="navbar-brand" title="訊息公告系統" href="mp?mp=9000"><img src="public/LayoutDesign/1441075792671.jpg" alt="訊息公告系統" title="訊息公告系統"></a>
# </div>
# <div class="collapse navbar-collapse navbar-ex1-collapse">
# <a href="#" accesskey="U" class="accesskey" title="上方導覽區塊">:::</a><ul  class="nav navbar-nav navbar-right">
# <li>
# <a title="回首頁" href="mp?mp=9000">回首頁</a>
# </li>
# <li>
# <a title="網站地圖" href="sitemap?mp=9000">網站地圖</a>
# </li>
# <li>
# <a title="逢甲大學" href="http://www.fcu.edu.tw">逢甲大學</a>
# </li>
# <li>
# <a title="英文" href="http://news.fcu.edu.tw/wSite/lp?ctNode=19614&mp=9002">English News</a>
# </li>
# </ul><form class="navbar-form navbar-right" method="GET" action="http://www.google.com/search" target="new">
#  <input title="search" name="q" type="text" class="inputSearch" id="q" onFocus="if(this.value=='Google Search')this.value=''" onBlur="if(this.value=='')this.value='Google Search'" value="Google Search" size="20" maxlength="255">
# <input type="hidden" name="sitesearch" value="子網域.fcu.edu.tw">
# <input type="submit" class="btnSearch" value="查詢" title="查詢"/>
# </form></div>
# </nav>
# </div>
# </div>
# </div>
# </nav>
# </header>
# <div class="container minu">
# <div class="row">
# <div class="col-sm-12 column">
# <div class="main">
# <nav id="cbp-hrmenu" class="cbp-hrmenu">
# <h2 class="hidden">分眾目錄</h2>
# <ul>
# <li>
# <a href="np?ctNode=17490&mp=9000&idPath=17482_17490" title="獎勵大學教學卓越計畫">獎勵大學教學卓越計畫</a>
# </li>
# <li>
# <a href="http://news.fcu.edu.tw/wSite/mp?mp=101001&ctNode=41204&idPath=17482_41204" title="逢甲快訊">逢甲快訊</a>
# </li>
# <li>
# <a href="http://news.fcu.edu.tw/wSite/mp?mp=204501&ctNode=41205&idPath=17482_41205" title="逢甲週報">逢甲週報</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# 		<a onfocus="mlout();" href="javascript:"></a>
# 		<noscript>TAB標籤效果，如不執行不影響您資料瀏覽</noscript>
# <div class="container">
# <div class="row page-wrap">
# <div class="col-md-12 col-sm-12 center_main">
# <div class="accesskey">
# <a href="#" accesskey="C" title="中央內容區塊">:::</a>
# </div>
# <div id="zone.content">
# <div class="friendly">
# <div class="path">
# <span class="before">現在位置</span>：<a href="mp?mp=9000" title="首頁">首頁</a>
# 				>
# 				<a href="np?ctNode=14979&mp=9000" title="逢甲大學">逢甲大學</a>
# 				>
# 				<a href="np?ctNode=15361&mp=9000" title="校園活動">校園活動</a>
# </div>
# <div class="function">
# <ul>
# <li>
# <a href="javascript:history.back();" class="back" title="回上一頁">回上一頁</a>
# <noscript>當script無法執行時可按"alt + &larr;"鍵替代</noscript>
# </li>
# </ul>
# </div>
# </div>
# <div class="lp">
# <h1>
# <span>校園活動</span>
# </h1>
# <table cellpadding="0" cellspacing="0" class="tb" summary="校園活動">
# <caption>校園活動</caption>
# <tr>
# <th scope="col">張貼日</th><th scope="col">標題</th><th scope="col">開始時間</th><th scope="col">截止時間</th>
# </tr>
# <tr>
# <td>2018-07-30</td><td class="title"><a href="ct?xItem=11A501366180B54D482582DA002C637C&ctNode=15361&mp=9000">9月4日(二)~9月5日(三)「2018暑假 SAS 資料分析與機器學習師資營」報名通知</a></td><td>2018-09-03</td><td>2018-09-04</td>
# </tr>
# <tr>
# <td>2018-06-14</td><td class="title"><a href="ct?xItem=9B1063BAB83F7581482582AC00013AC6&ctNode=15361&mp=9000">外籍生期末微積分補救教學(全英語)</a></td><td>2018-06-20</td><td>2018-06-21</td>
# </tr>
# <tr>
# <td>2018-06-13</td><td class="title"><a href="ct?xItem=5D98DE69AD8854EA482582AB00238093&ctNode=15361&mp=9000">106學年度第二學期會計系教學助理期末座談</a></td><td>2018-06-21</td><td>2018-06-21</td>
# </tr>
# <tr>
# <td>2018-06-12</td><td class="title"><a href="ct?xItem=7510F18BCD6632BA482582AA002A4EEA&ctNode=15361&mp=9000">106學年度第2學期外文系校外實習導論課程演講</a></td><td>2018-06-21</td><td>2018-06-22</td>
# </tr>
# <tr>
# <td>2018-06-11</td><td class="title"><a href="ct?xItem=36A34D13DCF00AB8482582A4000D074E&ctNode=15361&mp=9000">電聲碩士學位學程106學年度暑期海外專業實習</a></td><td>2018-07-02</td><td>2018-07-13</td>
# </tr>
# <tr>
# <td>2018-06-07</td><td class="title"><a href="ct?xItem=B3188AF681CD01DC482582A4000C0851&ctNode=15361&mp=9000">106-2「體驗式寫作」採訪攝影研習工作坊</a></td><td>2018-06-10</td><td>2018-06-10</td>
# </tr>
# <tr>
# <td>2018-06-04</td><td class="title"><a href="ct?xItem=8B460B2AD8FA30AF4825829B00141E39&ctNode=15361&mp=9000">2018逢甲大學學用合一「統計學應用競賽」總決賽</a></td><td>2018-06-08</td><td>2018-06-08</td>
# </tr>
# <tr>
# <td>2018-06-01</td><td class="title"><a href="ct?xItem=4CF4446EEDA844DA4825829F0010B818&ctNode=15361&mp=9000">資訊系演講：深度學習之實務經驗分享</a></td><td>2018-06-07</td><td>2018-06-07</td>
# </tr>
# <tr>
# <td>2018-05-31</td><td class="title"><a href="ct?xItem=057D1431AA600C934825829E002C155D&ctNode=15361&mp=9000">外文系專題演講：翻譯中國文化的挑戰與成功</a></td><td>2018-06-06</td><td>2018-06-06</td>
# </tr>
# <tr>
# <td>2018-05-30</td><td class="title"><a href="ct?xItem=425D2CB3D976DE874825829D002FEDF7&ctNode=15361&mp=9000">外文系專題演講--CDIO 融入教學與實踐</a></td><td>2018-06-06</td><td>2018-06-06</td>
# </tr>
# <tr>
# <td>2018-05-30</td><td class="title"><a href="ct?xItem=7480D110FE8C291C4825829D0032B649&ctNode=15361&mp=9000">「2018 暑假 MATLAB & Simulink 訓練課程」開始報名</a></td><td>2018-07-09</td><td>2018-07-17</td>
# </tr>
# <tr>
# <td>2018-05-23</td><td class="title"><a href="ct?xItem=0C76F47C5DAE551C482582960013DDBD&ctNode=15361&mp=9000">106學年度第2學期外文系深碗課程成果發表會</a></td><td>2018-05-31</td><td>2018-06-06</td>
# </tr>
# <tr>
# <td>2018-05-17</td><td class="title"><a href="ct?xItem=F59014B6F4AF718C48258290003115B9&ctNode=15361&mp=9000">資訊系演講：漫談人工智慧</a></td><td>2018-05-18</td><td>2018-05-18</td>
# </tr>
# <tr>
# <td>2018-05-16</td><td class="title"><a href="ct?xItem=73721D9458026E134825828E0014F559&ctNode=15361&mp=9000">電聲碩士學位學程106學年度校外教學參訪活動</a></td><td>2018-06-20</td><td>2018-06-20</td>
# </tr>
# <tr>
# <td>2018-05-14</td><td class="title"><a href="ct?xItem=09179A58E55ABB584825828D000C1534&ctNode=15361&mp=9000">資訊系演講：幸福正能量：&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;做自己的圓夢大使</a></td><td>2018-05-14</td><td>2018-05-17</td>
# </tr>
# </table>
# </div>
# <div class="quickLink">
# <ul>
# <li>
# <a href="#top" class="gotop" title="回頁首">回頁首</a>
# </li>
# <li>
# <a href="javascript:history.back();" class="back" title="回上一頁">回上一頁</a>
# <noscript>當script無法執行時可按"alt + &larr;"鍵替代</noscript>
# </li>
# <li style="display:none;">lp.xsl:FLP_MsgBoardImg,cp.xsl:FCUNews_EventCP</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <div class="row clearfix">
# <div class="col-md-12 column">
# <div class="footer">
# <div class="w3c">
# <a href="http://validator.w3.org/check?uri=referer"><img src="http://www.w3.org/Icons/valid-xhtml10" alt="Valid XHTML 1.0 Transitional" height="31" width="88"></a>
# </div>
# <div class="copyright">
# 			　</div><div class="logo"><img src="images/footer_logo.png" alt="footer_logo"></div>
# <p style="margin-top:30px;">Copyright©逢甲大學Feng Chia University
# <br>台中市西屯區文華路100號+886-4-24517250 | <a href="lp?ctNode=16062&mp=1"><font color="FFFFFF">隱私權聲明</a></p><div class="visitor">瀏覽人次<em>29324209</em>
# </div>
# <div class="update">更新日期<em>2018年08月29日</em>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript" src="styles/fcu_www_rwd_all/js/cbpHorizontalMenu.min.js"></script><script type="text/javascript">
# 					window.addEvent('domready', function(){
# 						if(widgets.widgets.length!=0){
# 							initApp();
# 						}
# 					});
# 				</script>
# <noscript>TAB標籤效果，如不執行不影響您資料瀏覽</noscript>
# </body>
# </html>

# %%
soup=BeautifulSoup(req.text,'lxml')
print(soup.get_text())
# Out:
# 逢甲大學新聞中心-校園活動
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			$(function() {
# 				cbpHorizontalMenu.init();
# 			});
#
#
#
#
#
#
#
#
#
#
# 導覽列開關
#
#
# :::
#
# 回首頁
#
#
# 網站地圖
#
#
# 逢甲大學
#
#
# English News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 分眾目錄
#
#
# 獎勵大學教學卓越計畫
#
#
# 逢甲快訊
#
#
# 逢甲週報
#
#
#
#
#
#
#
#
# TAB標籤效果，如不執行不影響您資料瀏覽
#
#
#
#
# :::
#
#
#
#
# 現在位置：首頁
# 				>
# 				逢甲大學
# 				>
# 				校園活動
#
#
#
#
# 回上一頁
# 當script無法執行時可按"alt + ←"鍵替代
#
#
#
#
#
#
# 校園活動
#
#
# 校園活動
#
# 張貼日標題開始時間截止時間
#
#
# 2018-07-309月4日(二)~9月5日(三)「2018暑假 SAS 資料分析與機器學習師資營」報名通知2018-09-032018-09-04
#
#
# 2018-06-14外籍生期末微積分補救教學(全英語)2018-06-202018-06-21
#
#
# 2018-06-13106學年度第二學期會計系教學助理期末座談2018-06-212018-06-21
#
#
# 2018-06-12106學年度第2學期外文系校外實習導論課程演講2018-06-212018-06-22
#
#
# 2018-06-11電聲碩士學位學程106學年度暑期海外專業實習2018-07-022018-07-13
#
#
# 2018-06-07106-2「體驗式寫作」採訪攝影研習工作坊2018-06-102018-06-10
#
#
# 2018-06-042018逢甲大學學用合一「統計學應用競賽」總決賽2018-06-082018-06-08
#
#
# 2018-06-01資訊系演講：深度學習之實務經驗分享2018-06-072018-06-07
#
#
# 2018-05-31外文系專題演講：翻譯中國文化的挑戰與成功2018-06-062018-06-06
#
#
# 2018-05-30外文系專題演講--CDIO 融入教學與實踐2018-06-062018-06-06
#
#
# 2018-05-30「2018 暑假 MATLAB & Simulink 訓練課程」開始報名2018-07-092018-07-17
#
#
# 2018-05-23106學年度第2學期外文系深碗課程成果發表會2018-05-312018-06-06
#
#
# 2018-05-17資訊系演講：漫談人工智慧2018-05-182018-05-18
#
#
# 2018-05-16電聲碩士學位學程106學年度校外教學參訪活動2018-06-202018-06-20
#
#
# 2018-05-14資訊系演講：幸福正能量：                做自己的圓夢大使2018-05-142018-05-17
#
#
#
#
#
#
# 回頁首
#
#
# 回上一頁
# 當script無法執行時可按"alt + ←"鍵替代
#
# lp.xsl:FLP_MsgBoardImg,cp.xsl:FCUNews_EventCP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Copyright©逢甲大學Feng Chia University
# 台中市西屯區文華路100號+886-4-24517250 | 隱私權聲明瀏覽人次29324209
#
# 更新日期2018年08月29日
#
#
#
#
#
#
# 					window.addEvent('domready', function(){
# 						if(widgets.widgets.length!=0){
# 							initApp();
# 						}
# 					});
#
# TAB標籤效果，如不執行不影響您資料瀏覽

# %%
dataTittle = soup.find('div',{'class':'lp'}).find_all('a')
print(dataTittle)
# Out:
# [<a href="ct?xItem=09179A58E55ABB584825828D000C1534&amp;ctNode=15361&amp;mp=9000">資訊系演講：幸福正能量：                做自己的圓夢大使</a>, <a href="ct?xItem=11A501366180B54D482582DA002C637C&amp;ctNode=15361&amp;mp=9000">9月4日(二)~9月5日(三)「2018暑假 SAS 資料分析與機器學習師資營」報名通知</a>, <a href="ct?xItem=9B1063BAB83F7581482582AC00013AC6&amp;ctNode=15361&amp;mp=9000">外籍生期末微積分補救教學(全英語)</a>, <a href="ct?xItem=5D98DE69AD8854EA482582AB00238093&amp;ctNode=15361&amp;mp=9000">106學年度第二學期會計系教學助理期末座談</a>, <a href="ct?xItem=7510F18BCD6632BA482582AA002A4EEA&amp;ctNode=15361&amp;mp=9000">106學年度第2學期外文系校外實習導論課程演講</a>, <a href="ct?xItem=36A34D13DCF00AB8482582A4000D074E&amp;ctNode=15361&amp;mp=9000">電聲碩士學位學程106學年度暑期海外專業實習</a>, <a href="ct?xItem=B3188AF681CD01DC482582A4000C0851&amp;ctNode=15361&amp;mp=9000">106-2「體驗式寫作」採訪攝影研習工作坊</a>, <a href="ct?xItem=8B460B2AD8FA30AF4825829B00141E39&amp;ctNode=15361&amp;mp=9000">2018逢甲大學學用合一「統計學應用競賽」總決賽</a>, <a href="ct?xItem=4CF4446EEDA844DA4825829F0010B818&amp;ctNode=15361&amp;mp=9000">資訊系演講：深度學習之實務經驗分享</a>, <a href="ct?xItem=057D1431AA600C934825829E002C155D&amp;ctNode=15361&amp;mp=9000">外文系專題演講：翻譯中國文化的挑戰與成功</a>, <a href="ct?xItem=425D2CB3D976DE874825829D002FEDF7&amp;ctNode=15361&amp;mp=9000">外文系專題演講--CDIO 融入教學與實踐</a>, <a href="ct?xItem=7480D110FE8C291C4825829D0032B649&amp;ctNode=15361&amp;mp=9000">「2018 暑假 MATLAB &amp; Simulink 訓練課程」開始報名</a>, <a href="ct?xItem=0C76F47C5DAE551C482582960013DDBD&amp;ctNode=15361&amp;mp=9000">106學年度第2學期外文系深碗課程成果發表會</a>, <a href="ct?xItem=F59014B6F4AF718C48258290003115B9&amp;ctNode=15361&amp;mp=9000">資訊系演講：漫談人工智慧</a>, <a href="ct?xItem=73721D9458026E134825828E0014F559&amp;ctNode=15361&amp;mp=9000">電聲碩士學位學程106學年度校外教學參訪活動</a>]

# %%
import pymysql
from flask import Flask,jsonify
from flask_sqlalchemy import  SQLAlchemy
from flask import request
import json
